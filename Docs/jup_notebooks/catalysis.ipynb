# %%
# %pip install numpy
# %pip install seaborn
# %pip install matplotlib
# %pip install statsmodels
# %pip install numdifftools

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys

# %%
sys.path.append('../../installation/build/lib')
from sofia import distributions as dist
from sofia import Sobol as sbl

# %%
# 1D Uniform
hyp = [[-8.,8.]]

D = dist.Uniform(1,hyp)

x = np.linspace(-10.,10.,1000)

plt.plot(x,D.get_cdf_values(x))
plt.title('Uniform CDF')
plt.show()

sns.kdeplot(D.get_samples(10000),shade=True)
plt.title('Uniform PDF')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f3c35185c79f> in <module>
# ----> 1 SA = sbl.Sobol() # Instantiation of sensitivity analysis object
#       2
#       3 sampls = sbl.sampling_sequence(10000,3,['uniform','uniform','uniform'],None)
#       4
#       5 f = np.zeros((len(sampls),1))
#
# TypeError: __init__() missing 2 required positional arguments: 'd' and 'hyperparams'
