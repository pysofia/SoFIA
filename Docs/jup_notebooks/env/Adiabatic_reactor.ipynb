# %%
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler
import sys
sys.path.append('../../../installation/build/lib') # Your path to sofia
import sofia.Sobol as sbl
import sofia.distributions as dist

# %%
# Plotting settings

SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 18

plt.rc('axes', titlesize=SMALL_SIZE)  # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)  # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)  # fontsize of the tick labels
cc = cycler('linestyle', ['-', '--', ':', '-.', '-']) * cycler('color', ['r', 'g', 'b', 'm', 'k'])
plt.rc('axes', prop_cycle=cc)

plt.rc('text', usetex=True)
plt.rc('font', family='Helvetica')

# %%
##

N=10000
d=6
## Input distributions ##
hyp = [[20.,22.],[20.,22.],[10.,15.],[10.,15.],[10.,15.],[10000.,15000.]]
input_distr = dist.Uniform(6,hyp)

SA = sbl.Sobol(6,hyp) # Instantiation of sensitivity analysis object

# %%
time_steps = 1002
time = [0]*time_steps
time_final = 1.e-7
for i in range(time_steps):
    time[i] += (i+1)*np.divide(time_final,time_steps)

ind = np.zeros((time_steps,6))
ind_T = np.zeros((time_steps,6))

ind_all = [[0.]*2]

func = np.zeros((N*(d+2),time_steps))

# %%
for j in range(N*(d+2)):
    func[j] = np.loadtxt('/Users/anabel/Documents/PhD/Code/SoFIA/Applications/examples/adiabatic_reactor/SA/output/temp_profile_Tinit_'+str(j)+'.dat')

for i in range(time_steps):
    f = [[0.]]*N*(d+2)
    for j in range(N*(d+2)):
        f[j] = [func[j,i]]

    s = SA.indices(f,N,6)
    ind[i] = s[0]
    ind_T[i] = s[1]
    print('Computed index for time step = '+str(i))
# Out:
# Computed index for time step = 0
# Computed index for time step = 1
# Computed index for time step = 2
# Computed index for time step = 3
# Computed index for time step = 4
# Computed index for time step = 5
# Computed index for time step = 6
# Computed index for time step = 7
# Computed index for time step = 8
# Computed index for time step = 9
# Computed index for time step = 10
# Computed index for time step = 11
# Computed index for time step = 12
# Computed index for time step = 13
# Computed index for time step = 14
# Computed index for time step = 15
# Computed index for time step = 16
# Computed index for time step = 17
# Computed index for time step = 18
# Computed index for time step = 19
# Computed index for time step = 20
# Computed index for time step = 21
# Computed index for time step = 22
# Computed index for time step = 23
# Computed index for time step = 24
# Computed index for time step = 25
# Computed index for time step = 26
# Computed index for time step = 27
# Computed index for time step = 28
# Computed index for time step = 29
# Computed index for time step = 30
# Computed index for time step = 31
# Computed index for time step = 32
# Computed index for time step = 33
# Computed index for time step = 34
# Computed index for time step = 35
# Computed index for time step = 36
# Computed index for time step = 37
# Computed index for time step = 38
# Computed index for time step = 39
# Computed index for time step = 40
# Computed index for time step = 41
# Computed index for time step = 42
# Computed index for time step = 43
# Computed index for time step = 44
# Computed index for time step = 45
# Computed index for time step = 46
# Computed index for time step = 47
# Computed index for time step = 48
# Computed index for time step = 49
# Computed index for time step = 50
# Computed index for time step = 51
# Computed index for time step = 52
# Computed index for time step = 53
# Computed index for time step = 54
# Computed index for time step = 55
# Computed index for time step = 56
# Computed index for time step = 57
# Computed index for time step = 58
# Computed index for time step = 59
# Computed index for time step = 60
# Computed index for time step = 61
# Computed index for time step = 62
# Computed index for time step = 63
# Computed index for time step = 64
# Computed index for time step = 65
# Computed index for time step = 66
# Computed index for time step = 67
# Computed index for time step = 68
# Computed index for time step = 69
# Computed index for time step = 70
# Computed index for time step = 71
# Computed index for time step = 72
# Computed index for time step = 73
# Computed index for time step = 74
# Computed index for time step = 75
# Computed index for time step = 76
# Computed index for time step = 77
# Computed index for time step = 78
# Computed index for time step = 79
# Computed index for time step = 80
# Computed index for time step = 81
# Computed index for time step = 82
# Computed index for time step = 83
# Computed index for time step = 84
# Computed index for time step = 85
# Computed index for time step = 86
# Computed index for time step = 87
# Computed index for time step = 88
# Computed index for time step = 89
# Computed index for time step = 90
# Computed index for time step = 91
# Computed index for time step = 92
# Computed index for time step = 93
# Computed index for time step = 94
# Computed index for time step = 95
# Computed index for time step = 96
# Computed index for time step = 97
# Computed index for time step = 98
# Computed index for time step = 99
# Computed index for time step = 100
# Computed index for time step = 101
# Computed index for time step = 102
# Computed index for time step = 103
# Computed index for time step = 104
# Computed index for time step = 105
# Computed index for time step = 106
# Computed index for time step = 107
# Computed index for time step = 108
# Computed index for time step = 109
# Computed index for time step = 110
# Computed index for time step = 111
# Computed index for time step = 112
# Computed index for time step = 113
# Computed index for time step = 114
# Computed index for time step = 115
# Computed index for time step = 116
# Computed index for time step = 117
# Computed index for time step = 118
# Computed index for time step = 119
# Computed index for time step = 120
# Computed index for time step = 121
# Computed index for time step = 122
# Computed index for time step = 123
# Computed index for time step = 124
# Computed index for time step = 125
# Computed index for time step = 126
# Computed index for time step = 127
# Computed index for time step = 128
# Computed index for time step = 129
# Computed index for time step = 130
# Computed index for time step = 131
# Computed index for time step = 132
# Computed index for time step = 133
# Computed index for time step = 134
# Computed index for time step = 135
# Computed index for time step = 136
# Computed index for time step = 137
# Computed index for time step = 138
# Computed index for time step = 139
# Computed index for time step = 140
# Computed index for time step = 141
# Computed index for time step = 142
# Computed index for time step = 143
# Computed index for time step = 144
# Computed index for time step = 145
# Computed index for time step = 146
# Computed index for time step = 147
# Computed index for time step = 148
# Computed index for time step = 149
# Computed index for time step = 150
# Computed index for time step = 151
# Computed index for time step = 152
# Computed index for time step = 153
# Computed index for time step = 154
# Computed index for time step = 155
# Computed index for time step = 156
# Computed index for time step = 157
# Computed index for time step = 158
# Computed index for time step = 159
# Computed index for time step = 160
# Computed index for time step = 161
# Computed index for time step = 162
# Computed index for time step = 163
# Computed index for time step = 164
# Computed index for time step = 165
# Computed index for time step = 166
# Computed index for time step = 167
# Computed index for time step = 168
# Computed index for time step = 169
# Computed index for time step = 170
# Computed index for time step = 171
# Computed index for time step = 172
# Computed index for time step = 173
# Computed index for time step = 174
# Computed index for time step = 175
# Computed index for time step = 176
# Computed index for time step = 177
# Computed index for time step = 178
# Computed index for time step = 179
# Computed index for time step = 180
# Computed index for time step = 181
# Computed index for time step = 182
# Computed index for time step = 183
# Computed index for time step = 184
# Computed index for time step = 185
# Computed index for time step = 186
# Computed index for time step = 187
# Computed index for time step = 188
# Computed index for time step = 189
# Computed index for time step = 190
# Computed index for time step = 191
# Computed index for time step = 192
# Computed index for time step = 193
# Computed index for time step = 194
# Computed index for time step = 195
# Computed index for time step = 196
# Computed index for time step = 197
# Computed index for time step = 198
# Computed index for time step = 199
# Computed index for time step = 200
# Computed index for time step = 201
# Computed index for time step = 202
# Computed index for time step = 203
# Computed index for time step = 204
# Computed index for time step = 205
# Computed index for time step = 206
# Computed index for time step = 207
# Computed index for time step = 208
# Computed index for time step = 209
# Computed index for time step = 210
# Computed index for time step = 211
# Computed index for time step = 212
# Computed index for time step = 213
# Computed index for time step = 214
# Computed index for time step = 215
# Computed index for time step = 216
# Computed index for time step = 217
# Computed index for time step = 218
# Computed index for time step = 219
# Computed index for time step = 220
# Computed index for time step = 221
# Computed index for time step = 222
# Computed index for time step = 223
# Computed index for time step = 224
# Computed index for time step = 225
# Computed index for time step = 226
# Computed index for time step = 227
# Computed index for time step = 228
# Computed index for time step = 229
# Computed index for time step = 230
# Computed index for time step = 231
# Computed index for time step = 232
# Computed index for time step = 233
# Computed index for time step = 234
# Computed index for time step = 235
# Computed index for time step = 236
# Computed index for time step = 237
# Computed index for time step = 238
# Computed index for time step = 239
# Computed index for time step = 240
# Computed index for time step = 241
# Computed index for time step = 242
# Computed index for time step = 243
# Computed index for time step = 244
# Computed index for time step = 245
# Computed index for time step = 246
# Computed index for time step = 247
# Computed index for time step = 248
# Computed index for time step = 249
# Computed index for time step = 250
# Computed index for time step = 251
# Computed index for time step = 252
# Computed index for time step = 253
# Computed index for time step = 254
# Computed index for time step = 255
# Computed index for time step = 256
# Computed index for time step = 257
# Computed index for time step = 258
# Computed index for time step = 259
# Computed index for time step = 260
# Computed index for time step = 261
# Computed index for time step = 262
# Computed index for time step = 263
# Computed index for time step = 264
# Computed index for time step = 265
# Computed index for time step = 266
# Computed index for time step = 267
# Computed index for time step = 268
# Computed index for time step = 269
# Computed index for time step = 270
# Computed index for time step = 271
# Computed index for time step = 272
# Computed index for time step = 273
# Computed index for time step = 274
# Computed index for time step = 275
# Computed index for time step = 276
# Computed index for time step = 277
# Computed index for time step = 278
# Computed index for time step = 279
# Computed index for time step = 280
# Computed index for time step = 281
# Computed index for time step = 282
# Computed index for time step = 283
# Computed index for time step = 284
# Computed index for time step = 285
# Computed index for time step = 286
# Computed index for time step = 287
# Computed index for time step = 288
# Computed index for time step = 289
# Computed index for time step = 290
# Computed index for time step = 291
# Computed index for time step = 292
# Computed index for time step = 293
# Computed index for time step = 294
# Computed index for time step = 295
# Computed index for time step = 296
# Computed index for time step = 297
# Computed index for time step = 298
# Computed index for time step = 299
# Computed index for time step = 300
# Computed index for time step = 301
# Computed index for time step = 302
# Computed index for time step = 303
# Computed index for time step = 304
# Computed index for time step = 305
# Computed index for time step = 306
# Computed index for time step = 307
# Computed index for time step = 308
# Computed index for time step = 309
# Computed index for time step = 310
# Computed index for time step = 311
# Computed index for time step = 312
# Computed index for time step = 313
# Computed index for time step = 314
# Computed index for time step = 315
# Computed index for time step = 316
# Computed index for time step = 317
# Computed index for time step = 318
# Computed index for time step = 319
# Computed index for time step = 320
# Computed index for time step = 321
# Computed index for time step = 322
# Computed index for time step = 323
# Computed index for time step = 324
# Computed index for time step = 325
# Computed index for time step = 326
# Computed index for time step = 327
# Computed index for time step = 328
# Computed index for time step = 329
# Computed index for time step = 330
# Computed index for time step = 331
# Computed index for time step = 332
# Computed index for time step = 333
# Computed index for time step = 334
# Computed index for time step = 335
# Computed index for time step = 336
# Computed index for time step = 337
# Computed index for time step = 338
# Computed index for time step = 339
# Computed index for time step = 340
# Computed index for time step = 341
# Computed index for time step = 342
# Computed index for time step = 343
# Computed index for time step = 344
# Computed index for time step = 345
# Computed index for time step = 346
# Computed index for time step = 347
# Computed index for time step = 348
# Computed index for time step = 349
# Computed index for time step = 350
# Computed index for time step = 351
# Computed index for time step = 352
# Computed index for time step = 353
# Computed index for time step = 354
# Computed index for time step = 355
# Computed index for time step = 356
# Computed index for time step = 357
# Computed index for time step = 358
# Computed index for time step = 359
# Computed index for time step = 360
# Computed index for time step = 361
# Computed index for time step = 362
# Computed index for time step = 363
# Computed index for time step = 364
# Computed index for time step = 365
# Computed index for time step = 366
# Computed index for time step = 367
# Computed index for time step = 368
# Computed index for time step = 369
# Computed index for time step = 370
# Computed index for time step = 371
# Computed index for time step = 372
# Computed index for time step = 373
# Computed index for time step = 374
# Computed index for time step = 375
# Computed index for time step = 376
# Computed index for time step = 377
# Computed index for time step = 378
# Computed index for time step = 379
# Computed index for time step = 380
# Computed index for time step = 381
# Computed index for time step = 382
# Computed index for time step = 383
# Computed index for time step = 384
# Computed index for time step = 385
# Computed index for time step = 386
# Computed index for time step = 387
# Computed index for time step = 388
# Computed index for time step = 389
# Computed index for time step = 390
# Computed index for time step = 391
# Computed index for time step = 392
# Computed index for time step = 393
# Computed index for time step = 394
# Computed index for time step = 395
# Computed index for time step = 396
# Computed index for time step = 397
# Computed index for time step = 398
# Computed index for time step = 399
# Computed index for time step = 400
# Computed index for time step = 401
# Computed index for time step = 402
# Computed index for time step = 403
# Computed index for time step = 404
# Computed index for time step = 405
# Computed index for time step = 406
# Computed index for time step = 407
# Computed index for time step = 408
# Computed index for time step = 409
# Computed index for time step = 410
# Computed index for time step = 411
# Computed index for time step = 412
# Computed index for time step = 413
# Computed index for time step = 414
# Computed index for time step = 415
# Computed index for time step = 416
# Computed index for time step = 417
# Computed index for time step = 418
# Computed index for time step = 419
# Computed index for time step = 420
# Computed index for time step = 421
# Computed index for time step = 422
# Computed index for time step = 423
# Computed index for time step = 424
# Computed index for time step = 425
# Computed index for time step = 426
# Computed index for time step = 427
# Computed index for time step = 428
# Computed index for time step = 429
# Computed index for time step = 430
# Computed index for time step = 431
# Computed index for time step = 432
# Computed index for time step = 433
# Computed index for time step = 434
# Computed index for time step = 435
# Computed index for time step = 436
# Computed index for time step = 437
# Computed index for time step = 438
# Computed index for time step = 439
# Computed index for time step = 440
# Computed index for time step = 441
# Computed index for time step = 442
# Computed index for time step = 443
# Computed index for time step = 444
# Computed index for time step = 445
# Computed index for time step = 446
# Computed index for time step = 447
# Computed index for time step = 448
# Computed index for time step = 449
# Computed index for time step = 450
# Computed index for time step = 451
# Computed index for time step = 452
# Computed index for time step = 453
# Computed index for time step = 454
# Computed index for time step = 455
# Computed index for time step = 456
# Computed index for time step = 457
# Computed index for time step = 458
# Computed index for time step = 459
# Computed index for time step = 460
# Computed index for time step = 461
# Computed index for time step = 462
# Computed index for time step = 463
# Computed index for time step = 464
# Computed index for time step = 465
# Computed index for time step = 466
# Computed index for time step = 467
# Computed index for time step = 468
# Computed index for time step = 469
# Computed index for time step = 470
# Computed index for time step = 471
# Computed index for time step = 472
# Computed index for time step = 473
# Computed index for time step = 474
# Computed index for time step = 475
# Computed index for time step = 476
# Computed index for time step = 477
# Computed index for time step = 478
# Computed index for time step = 479
# Computed index for time step = 480
# Computed index for time step = 481
# Computed index for time step = 482
# Computed index for time step = 483
# Computed index for time step = 484
# Computed index for time step = 485
# Computed index for time step = 486
# Computed index for time step = 487
# Computed index for time step = 488
# Computed index for time step = 489
# Computed index for time step = 490
# Computed index for time step = 491
# Computed index for time step = 492
# Computed index for time step = 493
# Computed index for time step = 494
# Computed index for time step = 495
# Computed index for time step = 496
# Computed index for time step = 497
# Computed index for time step = 498
# Computed index for time step = 499
# Computed index for time step = 500
# Computed index for time step = 501
# Computed index for time step = 502
# Computed index for time step = 503
# Computed index for time step = 504
# Computed index for time step = 505
# Computed index for time step = 506
# Computed index for time step = 507
# Computed index for time step = 508
# Computed index for time step = 509
# Computed index for time step = 510
# Computed index for time step = 511
# Computed index for time step = 512
# Computed index for time step = 513
# Computed index for time step = 514
# Computed index for time step = 515
# Computed index for time step = 516
# Computed index for time step = 517
# Computed index for time step = 518
# Computed index for time step = 519
# Computed index for time step = 520
# Computed index for time step = 521
# Computed index for time step = 522
# Computed index for time step = 523
# Computed index for time step = 524
# Computed index for time step = 525
# Computed index for time step = 526
# Computed index for time step = 527
# Computed index for time step = 528
# Computed index for time step = 529
# Computed index for time step = 530
# Computed index for time step = 531
# Computed index for time step = 532
# Computed index for time step = 533
# Computed index for time step = 534
# Computed index for time step = 535
# Computed index for time step = 536
# Computed index for time step = 537
# Computed index for time step = 538
# Computed index for time step = 539
# Computed index for time step = 540
# Computed index for time step = 541
# Computed index for time step = 542
# Computed index for time step = 543
# Computed index for time step = 544
# Computed index for time step = 545
# Computed index for time step = 546
# Computed index for time step = 547
# Computed index for time step = 548
# Computed index for time step = 549
# Computed index for time step = 550
# Computed index for time step = 551
# Computed index for time step = 552
# Computed index for time step = 553
# Computed index for time step = 554
# Computed index for time step = 555
# Computed index for time step = 556
# Computed index for time step = 557
# Computed index for time step = 558
# Computed index for time step = 559
# Computed index for time step = 560
# Computed index for time step = 561
# Computed index for time step = 562
# Computed index for time step = 563
# Computed index for time step = 564
# Computed index for time step = 565
# Computed index for time step = 566
# Computed index for time step = 567
# Computed index for time step = 568
# Computed index for time step = 569
# Computed index for time step = 570
# Computed index for time step = 571
# Computed index for time step = 572
# Computed index for time step = 573
# Computed index for time step = 574
# Computed index for time step = 575
# Computed index for time step = 576
# Computed index for time step = 577
# Computed index for time step = 578
# Computed index for time step = 579
# Computed index for time step = 580
# Computed index for time step = 581
# Computed index for time step = 582
# Computed index for time step = 583
# Computed index for time step = 584
# Computed index for time step = 585
# Computed index for time step = 586
# Computed index for time step = 587
# Computed index for time step = 588
# Computed index for time step = 589
# Computed index for time step = 590
# Computed index for time step = 591
# Computed index for time step = 592
# Computed index for time step = 593
# Computed index for time step = 594
# Computed index for time step = 595
# Computed index for time step = 596
# Computed index for time step = 597
# Computed index for time step = 598
# Computed index for time step = 599
# Computed index for time step = 600
# Computed index for time step = 601
# Computed index for time step = 602
# Computed index for time step = 603
# Computed index for time step = 604
# Computed index for time step = 605
# Computed index for time step = 606
# Computed index for time step = 607
# Computed index for time step = 608
# Computed index for time step = 609
# Computed index for time step = 610
# Computed index for time step = 611
# Computed index for time step = 612
# Computed index for time step = 613
# Computed index for time step = 614
# Computed index for time step = 615
# Computed index for time step = 616
# Computed index for time step = 617
# Computed index for time step = 618
# Computed index for time step = 619
# Computed index for time step = 620
# Computed index for time step = 621
# Computed index for time step = 622
# Computed index for time step = 623
# Computed index for time step = 624
# Computed index for time step = 625
# Computed index for time step = 626
# Computed index for time step = 627
# Computed index for time step = 628
# Computed index for time step = 629
# Computed index for time step = 630
# Computed index for time step = 631
# Computed index for time step = 632
# Computed index for time step = 633
# Computed index for time step = 634
# Computed index for time step = 635
# Computed index for time step = 636
# Computed index for time step = 637
# Computed index for time step = 638
# Computed index for time step = 639
# Computed index for time step = 640
# Computed index for time step = 641
# Computed index for time step = 642
# Computed index for time step = 643
# Computed index for time step = 644
# Computed index for time step = 645
# Computed index for time step = 646
# Computed index for time step = 647
# Computed index for time step = 648
# Computed index for time step = 649
# Computed index for time step = 650
# Computed index for time step = 651
# Computed index for time step = 652
# Computed index for time step = 653
# Computed index for time step = 654
# Computed index for time step = 655
# Computed index for time step = 656
# Computed index for time step = 657
# Computed index for time step = 658
# Computed index for time step = 659
# Computed index for time step = 660
# Computed index for time step = 661
# Computed index for time step = 662
# Computed index for time step = 663
# Computed index for time step = 664
# Computed index for time step = 665
# Computed index for time step = 666
# Computed index for time step = 667
# Computed index for time step = 668
# Computed index for time step = 669
# Computed index for time step = 670
# Computed index for time step = 671
# Computed index for time step = 672
# Computed index for time step = 673
# Computed index for time step = 674
# Computed index for time step = 675
# Computed index for time step = 676
# Computed index for time step = 677
# Computed index for time step = 678
# Computed index for time step = 679
# Computed index for time step = 680
# Computed index for time step = 681
# Computed index for time step = 682
# Computed index for time step = 683
# Computed index for time step = 684
# Computed index for time step = 685
# Computed index for time step = 686
# Computed index for time step = 687
# Computed index for time step = 688
# Computed index for time step = 689
# Computed index for time step = 690
# Computed index for time step = 691
# Computed index for time step = 692
# Computed index for time step = 693
# Computed index for time step = 694
# Computed index for time step = 695
# Computed index for time step = 696
# Computed index for time step = 697
# Computed index for time step = 698
# Computed index for time step = 699
# Computed index for time step = 700
# Computed index for time step = 701
# Computed index for time step = 702
# Computed index for time step = 703
# Computed index for time step = 704
# Computed index for time step = 705
# Computed index for time step = 706
# Computed index for time step = 707
# Computed index for time step = 708
# Computed index for time step = 709
# Computed index for time step = 710
# Computed index for time step = 711
# Computed index for time step = 712
# Computed index for time step = 713
# Computed index for time step = 714
# Computed index for time step = 715
# Computed index for time step = 716
# Computed index for time step = 717
# Computed index for time step = 718
# Computed index for time step = 719
# Computed index for time step = 720
# Computed index for time step = 721
# Computed index for time step = 722
# Computed index for time step = 723
# Computed index for time step = 724
# Computed index for time step = 725
# Computed index for time step = 726
# Computed index for time step = 727
# Computed index for time step = 728
# Computed index for time step = 729
# Computed index for time step = 730
# Computed index for time step = 731
# Computed index for time step = 732
# Computed index for time step = 733
# Computed index for time step = 734
# Computed index for time step = 735
# Computed index for time step = 736
# Computed index for time step = 737
# Computed index for time step = 738
# Computed index for time step = 739
# Computed index for time step = 740
# Computed index for time step = 741
# Computed index for time step = 742
# Computed index for time step = 743
# Computed index for time step = 744
# Computed index for time step = 745
# Computed index for time step = 746
# Computed index for time step = 747
# Computed index for time step = 748
# Computed index for time step = 749
# Computed index for time step = 750
# Computed index for time step = 751
# Computed index for time step = 752
# Computed index for time step = 753
# Computed index for time step = 754
# Computed index for time step = 755
# Computed index for time step = 756
# Computed index for time step = 757
# Computed index for time step = 758
# Computed index for time step = 759
# Computed index for time step = 760
# Computed index for time step = 761
# Computed index for time step = 762
# Computed index for time step = 763
# Computed index for time step = 764
# Computed index for time step = 765
# Computed index for time step = 766
# Computed index for time step = 767
# Computed index for time step = 768
# Computed index for time step = 769
# Computed index for time step = 770
# Computed index for time step = 771
# Computed index for time step = 772
# Computed index for time step = 773
# Computed index for time step = 774
# Computed index for time step = 775
# Computed index for time step = 776
# Computed index for time step = 777
# Computed index for time step = 778
# Computed index for time step = 779
# Computed index for time step = 780
# Computed index for time step = 781
# Computed index for time step = 782
# Computed index for time step = 783
# Computed index for time step = 784
# Computed index for time step = 785
# Computed index for time step = 786
# Computed index for time step = 787
# Computed index for time step = 788
# Computed index for time step = 789
# Computed index for time step = 790
# Computed index for time step = 791
# Computed index for time step = 792
# Computed index for time step = 793
# Computed index for time step = 794
# Computed index for time step = 795
# Computed index for time step = 796
# Computed index for time step = 797
# Computed index for time step = 798
# Computed index for time step = 799
# Computed index for time step = 800
# Computed index for time step = 801
# Computed index for time step = 802
# Computed index for time step = 803
# Computed index for time step = 804
# Computed index for time step = 805
# Computed index for time step = 806
# Computed index for time step = 807
# Computed index for time step = 808
# Computed index for time step = 809
# Computed index for time step = 810
# Computed index for time step = 811
# Computed index for time step = 812
# Computed index for time step = 813
# Computed index for time step = 814
# Computed index for time step = 815
# Computed index for time step = 816
# Computed index for time step = 817
# Computed index for time step = 818
# Computed index for time step = 819
# Computed index for time step = 820
# Computed index for time step = 821
# Computed index for time step = 822
# Computed index for time step = 823
# Computed index for time step = 824
# Computed index for time step = 825
# Computed index for time step = 826
# Computed index for time step = 827
# Computed index for time step = 828
# Computed index for time step = 829
# Computed index for time step = 830
# Computed index for time step = 831
# Computed index for time step = 832
# Computed index for time step = 833
# Computed index for time step = 834
# Computed index for time step = 835
# Computed index for time step = 836
# Computed index for time step = 837
# Computed index for time step = 838
# Computed index for time step = 839
# Computed index for time step = 840
# Computed index for time step = 841
# Computed index for time step = 842
# Computed index for time step = 843
# Computed index for time step = 844
# Computed index for time step = 845
# Computed index for time step = 846
# Computed index for time step = 847
# Computed index for time step = 848
# Computed index for time step = 849
# Computed index for time step = 850
# Computed index for time step = 851
# Computed index for time step = 852
# Computed index for time step = 853
# Computed index for time step = 854
# Computed index for time step = 855
# Computed index for time step = 856
# Computed index for time step = 857
# Computed index for time step = 858
# Computed index for time step = 859
# Computed index for time step = 860
# Computed index for time step = 861
# Computed index for time step = 862
# Computed index for time step = 863
# Computed index for time step = 864
# Computed index for time step = 865
# Computed index for time step = 866
# Computed index for time step = 867
# Computed index for time step = 868
# Computed index for time step = 869
# Computed index for time step = 870
# Computed index for time step = 871
# Computed index for time step = 872
# Computed index for time step = 873
# Computed index for time step = 874
# Computed index for time step = 875
# Computed index for time step = 876
# Computed index for time step = 877
# Computed index for time step = 878
# Computed index for time step = 879
# Computed index for time step = 880
# Computed index for time step = 881
# Computed index for time step = 882
# Computed index for time step = 883
# Computed index for time step = 884
# Computed index for time step = 885
# Computed index for time step = 886
# Computed index for time step = 887
# Computed index for time step = 888
# Computed index for time step = 889
# Computed index for time step = 890
# Computed index for time step = 891
# Computed index for time step = 892
# Computed index for time step = 893
# Computed index for time step = 894
# Computed index for time step = 895
# Computed index for time step = 896
# Computed index for time step = 897
# Computed index for time step = 898
# Computed index for time step = 899
# Computed index for time step = 900
# Computed index for time step = 901
# Computed index for time step = 902
# Computed index for time step = 903
# Computed index for time step = 904
# Computed index for time step = 905
# Computed index for time step = 906
# Computed index for time step = 907
# Computed index for time step = 908
# Computed index for time step = 909
# Computed index for time step = 910
# Computed index for time step = 911
# Computed index for time step = 912
# Computed index for time step = 913
# Computed index for time step = 914
# Computed index for time step = 915
# Computed index for time step = 916
# Computed index for time step = 917
# Computed index for time step = 918
# Computed index for time step = 919
# Computed index for time step = 920
# Computed index for time step = 921
# Computed index for time step = 922
# Computed index for time step = 923
# Computed index for time step = 924
# Computed index for time step = 925
# Computed index for time step = 926
# Computed index for time step = 927
# Computed index for time step = 928
# Computed index for time step = 929
# Computed index for time step = 930
# Computed index for time step = 931
# Computed index for time step = 932
# Computed index for time step = 933
# Computed index for time step = 934
# Computed index for time step = 935
# Computed index for time step = 936
# Computed index for time step = 937
# Computed index for time step = 938
# Computed index for time step = 939
# Computed index for time step = 940
# Computed index for time step = 941
# Computed index for time step = 942
# Computed index for time step = 943
# Computed index for time step = 944
# Computed index for time step = 945
# Computed index for time step = 946
# Computed index for time step = 947
# Computed index for time step = 948
# Computed index for time step = 949
# Computed index for time step = 950
# Computed index for time step = 951
# Computed index for time step = 952
# Computed index for time step = 953
# Computed index for time step = 954
# Computed index for time step = 955
# Computed index for time step = 956
# Computed index for time step = 957
# Computed index for time step = 958
# Computed index for time step = 959
# Computed index for time step = 960
# Computed index for time step = 961
# Computed index for time step = 962
# Computed index for time step = 963
# Computed index for time step = 964
# Computed index for time step = 965
# Computed index for time step = 966
# Computed index for time step = 967
# Computed index for time step = 968
# Computed index for time step = 969
# Computed index for time step = 970
# Computed index for time step = 971
# Computed index for time step = 972
# Computed index for time step = 973
# Computed index for time step = 974
# Computed index for time step = 975
# Computed index for time step = 976
# Computed index for time step = 977
# Computed index for time step = 978
# Computed index for time step = 979
# Computed index for time step = 980
# Computed index for time step = 981
# Computed index for time step = 982
# Computed index for time step = 983
# Computed index for time step = 984
# Computed index for time step = 985
# Computed index for time step = 986
# Computed index for time step = 987
# Computed index for time step = 988
# Computed index for time step = 989
# Computed index for time step = 990
# Computed index for time step = 991
# Computed index for time step = 992
# Computed index for time step = 993
# Computed index for time step = 994
# Computed index for time step = 995
# Computed index for time step = 996
# Computed index for time step = 997
# Computed index for time step = 998
# Computed index for time step = 999
# Computed index for time step = 1000
# Computed index for time step = 1001

# %%
labels_T = {0: 'N2+M=2N+M', 1: 'O2+M=2O+M', 2: 'NO+M=N+O+M', 3: 'N2+O=NO+N', 4: 'NO+O=O2+N',5: '$T_{\mathrm{initial}}$'}

# plt.figure()
for i in range(5):
    plt.plot(time,ind_T[:,i],label=labels_T[i])

for i in range(4):
    plt.plot(time,ind[:,i])

plt.plot(time,ind[:,4],label='First order')

plt.plot(time,ind_T[:,5],label=labels_T[5])
plt.plot(time,ind[:,5],label=labels_T[5] + ' first order')

ax = plt.gca()
ax.yaxis.set_label_coords(0.0, 1.00)
plt.ylabel('Sobol indices', rotation=0)
plt.xlabel('time, s')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False) 
plt.ylim(0.,1.25)
plt.legend()
